# %%
import numpy as np

# %%
empty = np.zeros((5,5))
empty

full1 = np.ones((5,5)) * 255
full2 = np.zeros((5,5)) + 255
full3 = np.full((5,5), 255)
full1
full2
full3
# Out:
# array([[255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255]])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(empty)
plt.imshow(full)
# plt.show(empty)

# %%
# imsi1 = np.hstack((empty,full))
imsi1 = np.concatenate((empty,full), 1)
imsi1

imsi1_ = np.concatenate((full,empty), 1)
# imsi1_ = np.fliplr(imsi1)
imsi2 = np.concatenate((imsi1, imsi1_), 0)
# imsi2 = np.vstack((imsi1,imsi1_))

imsi3 = np.zeros((10, 200))
imsi3

for i in range(20):
    imsi3[:, i*10:i*10+10] = imsi2
    
imsi4 = np.zeros((200,200))

for i in range(20):
    imsi4[i*10:i*10+10,:] = imsi3
    

plt.imshow(imsi4)
# np.hstack((imsi1,imsi1))
# np.vstack((empty,full))

# %%
imsi3 = np.zeros((200,200))
imsi3
plt.imshow(imsi3)

# %%
# imsi3 = np.zeros((200,200))
# imsi3

empty = np.zeros((200,200))

full = np.ones((180,180))
empty[10:190, 10:190] = full

full = np.zeros((160,160))
empty[20:180, 20:180] = full

full = np.ones((140,140))
empty[30:170, 30:170] = full

full = np.zeros((120,120))
empty[40:160, 40:160] = full

full = np.ones((100,100))
empty[50:150, 50: 150] = full

full = np.zeros((80,80))
empty[60:140, 60: 140] = full

full = np.ones((60,60))
empty[70:130, 70: 130] = full

full = np.zeros((40,40))
empty[80:120, 80: 120] = full

full = np.ones((20,20))
empty[90:110, 90:110] = full

plt.imshow(empty)

# %%
empty = np.zeros((200,200))

for i in range(9):
    if i%2==0:
        full = np.full((200 - (i+1)*20, 200 - (i+1)*20), 255)
    else:
        full = np.full((200 - (i+1)*20, 200 - (i+1)*20), 0)
    empty[(i+1)*10:200 - (i+1)*10, (i+1)*10:200 - (i+1)*10] = full
plt.imshow(empty, 'gray')
plt.show()

# %%
empty = np.zeros((200,200))

full = np.ones((40,40))
empty[0:40, 0:40] = full

full = np.ones((40,40))
empty[40:80, 40:80] = full

full = np.ones((40,40))
empty[80:120, 80:120]= full

full = np.ones((40,40))
empty[120:160, 120:160]= full

full = np.ones((40,40))
empty[160:200, 160:200]= full

plt.imshow(empty, 'gray')

# %%
full = np.full((200,200))

for i in range(5):
    full = np.zeros()
# Out:
#   File "<ipython-input-379-ab35a7869764>", line 4
#     full = np.full(200-((i+1)*160)), 200-((i+1)*160))
#                                                     ^
# SyntaxError: unmatched ')'

# %%
full = np.ones((40,40))
empty = np.zeros((200,200))

for i in range(5):
    empty[i*40:(i+1)*40, i*40:(i+1)*40]=full
    
plt.imshow(empty)

# %%
empty = np.zeros((200,200))

for i in range(200):
    for j in range(200):
        empty[i,j] = np.sqrt((i-100)**2+(j-100)**2)
        
plt.imshow(empty < 100)

# %%
# empty = np.zeros((200,200))

# int1 = [0,120]
# int2 = [140,0]

# m = (140-0)/(0-120)

# for garo in range(200):
#     for sero in range(200):
#         if m*garo - sero < -140:
#             empty[sero, garo] = 255
            
# plt.imshow(empty, 'gray')
# plt.show()


empty1 = np.zeros((200,200))
empty2 = np.zeros((200,200))
empty3 = np.zeros((200,200))

point1 = [0,120]
point2 = [140, 0]
point3 = [150, 199]

m1 = (point2[0] - point1[0] / (point2[1]-point[1]))
m2 = (point3[0] - point1[0] / (point3[1]-point[1]))
m3 = (point3[0] - point2[0] / (point3[1]-point[1]))

for garo in range(200):
    for sero in range(200):
        if m1*garo - sero < -(point2[0])
# Out:
#   File "<ipython-input-441-b53a563427cf>", line 26
#     if m*garo - sero < -150
#                            ^
# SyntaxError: invalid syntax

# %%
empty = np.zeros((5,5))
full = np.full((5,5), 255)

imsi1 = np.concatenate((empty,full),0)
imsi1_= np.concatenate((full,empty),0)
imsi2 = np.concatenate((imsi1, imsi1_),1)

plt.imshow(imsi2)

# %%
imsi3 = np.zeros((10,200))
plt.imshow(imsi3)
# imsi3.shape
for i in range(20):
    imsi3[:, i*10:i*10+10]=imsi2
plt.imshow(imsi3)

# %%
imsi4 = np.zeros((200,200))
for i in range(20):
    imsi4[i*10:i*10+10, :]=imsi3
plt.imshow(imsi4)

# %%
imsi3 = np.zeros((200,200))

empty = np.zeros((200,200))
full = np.ones((180,180))
empty[10:190, 10:190] = full
plt.imshow(empty)

# %%
imsi = np.arange(10)
imsi

imsi < 5

imsi[imsi<5].sum()
# Out:
# 10

# %%
import PIL

pic = plt.imread("name.png")
# plt.imshow(pic)
# plt.show()

pic=pic[:,:,0]
plt.imshow(pic, cmap="gray")
pic == 0
np.where(pic == 0)

pic2 = np.logical_not(pic)
plt.imshow(pic2)

pic2.sum()
# Out:
# 101500
